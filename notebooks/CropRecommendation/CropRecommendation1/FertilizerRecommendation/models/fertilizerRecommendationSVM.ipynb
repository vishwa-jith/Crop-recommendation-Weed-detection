# %%
import pandas as pd
import numpy as np

# %%
fertilizerRecommendation=pd.read_csv("../../../../../preprocessedData/FertilizerPrediction.csv")
fertilizerRecommendation
# Out:
#     Unnamed: 0  Temparature  Humidity   Moisture  Soil Type  Crop Type  \
# 0            0           26         52        38          4          3
# 1            1           29         52        45          2          8
# 2            2           34         65        62          0          1
# 3            3           32         62        34          3          9
# 4            4           28         54        46          1          6
# ..         ...          ...        ...       ...        ...        ...
# 94          94           25         50        32          1          7
# 95          95           30         60        27          3          9
# 96          96           38         72        51          2         10
# 97          97           36         60        43          4          4
# 98          98           29         58        57          0          8
#
#     Nitrogen  Potassium  Phosphorous  Fertilizer Name
# 0         37          0            0                6
# 1         12          0           36                5
# 2          7          9           30                1
# 3         22          0           20                4
# 4         35          0            0                6
# ..       ...        ...          ...              ...
# 94        24          0           19                4
# 95         4         17           17                0
# 96        39          0            0                6
# 97        15          0           41                5
# 98        12          0           10                3
#
# [99 rows x 10 columns]

# %%
fertilizerRecommendation=fertilizerRecommendation.drop(columns=["Unnamed: 0"])
fertilizerRecommendation
# Out:
#     Temparature  Humidity   Moisture  Soil Type  Crop Type  Nitrogen  \
# 0            26         52        38          4          3        37
# 1            29         52        45          2          8        12
# 2            34         65        62          0          1         7
# 3            32         62        34          3          9        22
# 4            28         54        46          1          6        35
# ..          ...        ...       ...        ...        ...       ...
# 94           25         50        32          1          7        24
# 95           30         60        27          3          9         4
# 96           38         72        51          2         10        39
# 97           36         60        43          4          4        15
# 98           29         58        57          0          8        12
#
#     Potassium  Phosphorous  Fertilizer Name
# 0           0            0                6
# 1           0           36                5
# 2           9           30                1
# 3           0           20                4
# 4           0            0                6
# ..        ...          ...              ...
# 94          0           19                4
# 95         17           17                0
# 96          0            0                6
# 97          0           41                5
# 98          0           10                3
#
# [99 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
fertilizerRecommendation=fertilizerRecommendation.drop(columns=["Moisture"])
X=fertilizerRecommendation.drop(columns=["Fertilizer Name"])
y=fertilizerRecommendation["Fertilizer Name"]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X=scaler.fit_transform(X)
X
# Out:
# array([[-1.22908361, -1.2307368 ,  1.4178901 , -0.68850963,  1.56753938,
#         -0.58491041, -1.38760694],
#        [-0.36814533, -1.2307368 , -0.00719741,  0.91154796, -0.59865825,
#         -0.58491041,  1.29720909],
#        [ 1.06675181,  1.00649239, -1.43228493, -1.32853267, -1.03189778,
#          0.97077668,  0.84973976],
#        [ 0.49279296,  0.49020873,  0.70534635,  1.23155948,  0.2678208 ,
#         -0.58491041,  0.10395752],
#        [-0.65512475, -0.8865477 , -0.71974117,  0.27152493,  1.39424356,
#         -0.58491041, -1.38760694],
#        [-1.22908361, -1.2307368 ,  1.4178901 , -1.64854419, -0.59865825,
#          1.1436308 , -0.41809004],
#        [-1.51606304, -1.57492591,  0.70534635, -1.32853267, -0.85860197,
#         -0.58491041, -0.64182471],
#         -0.58491041, -0.26893359],
#        [-1.51606304, -1.57492591, -0.00719741,  0.91154796, -0.68530616,
#          1.66219316, -0.26893359],
#        [ 0.49279296,  0.49020873,  0.70534635, -1.00852115, -0.33871454,
#         -0.58491041,  1.37178732],
#        [-0.65512475, -0.8865477 , -0.71974117,  0.27152493,  1.48089147,
#         -0.58491041, -1.38760694],
#        [-0.0811659 ,  0.14601962, -0.00719741,  1.551571  , -0.51201035,
#         -0.58491041, -0.71640293],
#        [ 1.06675181,  1.00649239, -1.43228493, -1.32853267,  0.44111661,
#         -0.58491041,  0.10395752],
#        [-0.65512475, -0.8865477 ,  1.4178901 , -1.64854419, -1.20519359,
#          2.52646376, -0.26893359],
#        [-0.94210418, -1.05864225, -1.43228493, -0.04848659,  1.56753938,
#         -0.58491041, -1.38760694],
#        [ 1.64071067,  1.52277605,  0.70534635, -1.32853267, -0.33871454,
#         -0.58491041,  1.59552199],
#        [ 1.06675181,  1.00649239, -1.43228493,  0.91154796, -0.85860197,
#         -0.58491041, -0.41809004],
#        [-0.36814533, -0.19816949, -0.00719741,  0.91154796, -0.94524987,
#          0.79792256,  1.07347442],
#        [-1.51606304, -1.57492591, -0.71974117,  0.59153645, -1.11854568,
#          2.69931788, -0.19435537],
#        [-0.0811659 ,  0.14601962,  1.4178901 , -0.36849811, -0.77195406,
#         -0.58491041, -0.34351182],
#        [-1.22908361, -1.2307368 , -0.71974117,  0.59153645,  0.18117289,
#         -0.58491041,  0.32769219],
#        [ 0.20581353,  0.49020873,  0.70534635,  1.23155948,  1.74083519,
#         -0.58491041, -1.38760694],
#        [ 1.06675181,  1.00649239, -0.00719741,  1.551571  ,  0.3544687 ,
#         -0.58491041,  0.0293793 ],
#        [-0.94210418, -1.05864225, -1.43228493, -0.04848659,  2.0007789 ,
#         -0.58491041, -1.38760694],
#        [ 0.77977239,  0.83439783,  0.70534635, -1.00852115, -0.51201035,
#         -0.58491041,  1.52094376],
#        [-0.36814533, -0.19816949, -0.71974117,  0.27152493, -0.85860197,
#          1.1436308 ,  0.25311397],
#        [-0.0811659 ,  0.14601962,  1.4178901 , -0.68850963,  0.2678208 ,
#         -0.58491041,  0.17853575],
#        [-0.94210418, -1.05864225, -0.00719741,  0.91154796, -0.77195406,
#         -0.58491041, -0.26893359],
#        [-1.22908361, -1.2307368 , -0.71974117,  0.59153645, -1.03189778,
#          2.18075552,  0.10395752],
#        [ 1.06675181,  1.00649239,  0.70534635, -1.32853267, -0.42536244,
#         -0.58491041,  1.44636554],
#        [-0.65512475, -0.8865477 , -0.71974117,  0.27152493, -0.77195406,
#          0.79792256,  0.77516153],
#        [-0.0811659 ,  0.14601962,  1.4178901 , -0.36849811,  1.914131  ,
#         -0.58491041, -1.38760694],
#        [-0.36814533, -0.19816949, -1.43228493, -1.32853267, -0.42536244,
#         -0.58491041,  1.22263087],
#        [-1.22908361, -1.2307368 , -0.00719741,  0.91154796, -0.68530616,
#         -0.58491041, -0.71640293],
#        [ 0.20581353,  0.49020873,  1.4178901 , -1.64854419,  0.18117289,
#         -0.58491041,  0.70058331],
#        [ 1.35373124,  1.35068149, -0.71974117,  0.59153645, -0.94524987,
#          0.62506844,  0.92431798],
#        [-0.36814533, -0.19816949,  0.70534635,  1.23155948, -0.51201035,
#          2.35360964, -0.19435537],
#        [-0.94210418, -1.05864225, -1.43228493, -0.36849811,  1.39424356,
#         -0.58491041, -1.38760694],
#        [ 1.64071067,  1.52277605, -0.00719741,  1.551571  , -0.59865825,
#          2.52646376,  0.0293793 ],
#        [-0.36814533, -0.19816949, -0.00719741, -1.32853267, -0.68530616,
#         -0.58491041,  1.44636554],
#        [-0.0811659 ,  0.14601962, -1.43228493, -0.04848659, -0.94524987,
#          0.97077668,  0.84973976],
#        [ 1.06675181,  1.00649239, -0.71974117,  0.27152493, -1.11854568,
#          2.69931788,  0.17853575],
#        [ 1.64071067,  1.52277605,  0.70534635, -1.00852115,  1.914131  ,
#         -0.58491041, -1.38760694],
#        [-0.65512475, -0.8865477 ,  1.4178901 , -0.68850963, -0.85860197,
#          1.1436308 ,  0.84973976],
#        [-1.51606304, -1.57492591, -0.71974117,  0.59153645,  0.44111661,
#         -0.58491041,  0.0293793 ],
#        [-0.0811659 ,  0.14601962,  0.70534635,  1.23155948, -1.29184149,
#          2.35360964, -0.11977715],
#        [ 2.21466952,  2.21115426, -0.00719741,  1.551571  ,  1.74083519,
#         -0.58491041, -1.38760694],
#        [ 1.64071067,  0.14601962,  1.4178901 , -0.36849811, -0.33871454,
#         -0.58491041,  1.67010021],
#        [-0.36814533, -0.19816949, -1.43228493,  0.91154796, -0.59865825,
#         -0.58491041, -0.64182471]])

# %%
y
# Out:
# 0     6
# 1     5
# 2     1
# 3     4
# 4     6
#      ..
# 94    4
# 95    0
# 96    6
# 97    5
# 98    3
# Name: Fertilizer Name, Length: 99, dtype: int64

# %%
X_Train,X_Test,y_Train,y_Test=train_test_split(X,y,test_size=0.1,random_state=2)

# %%
from sklearn import svm
from sklearn.metrics import classification_report,accuracy_score

# %%
model=svm.SVC(kernel="linear")
model.fit(X_Train,y_Train)
# Out:
# SVC(kernel='linear')

# %%
predict_val=model.predict(X_Test)
predict_val
# Out:
# array([1, 4, 6, 3, 6, 6, 1, 6, 5, 4], dtype=int64)

# %%
y_Test
# Out:
# 93    1
# 30    4
# 56    6
# 24    3
# 16    6
# 23    6
# 2     1
# 27    6
# 28    5
# 13    4
# Name: Fertilizer Name, dtype: int64

# %%
accuracy_score(predict_val,y_Test)
# Out:
# 1.0

# %%
print(classification_report(predict_val,y_Test))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         2
#            5       1.00      1.00      1.00         1
#            6       1.00      1.00      1.00         4
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10

# %%
import pickle
pickle.dump(model, open("../../../../../pickledFiles/fertilizerRecommendation.pkl", "wb"))
